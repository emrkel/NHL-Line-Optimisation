# %% [markdown]
# # Data Collection
#
# To build this optimisation model, historical NHL player statistics have been collected and colated into various csv files by moneypuck.com. This project uses the following data:
#
# Data Source: https://www.moneypuck.com/data.htm
# Last updated at 2024-06-25 05:31 ET
#
# - Skaters (2019-2020 Season -> 2023-2024 Season)
# - Lines/Pairings (2019-2020 Season -> 2023-2024 Season)
# - Team Data (2019-2020 Season -> 2023-2024 Season)
# - Player Data (All Players from 2007 -> now, includes birthday, height, nationality, number, position and arm)
#
#
# ** Future endevour to automate the data using NHL's API's

# %%
# Import Required Libraries 

import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
# Read in files from /rawData 

# #skaters -  data consists of game data aggregated over the season for each player 
# in each game situation (eg. 5on5, 4on5, PP, etc. )

skaters19_20 = pd.read_csv("rawData/skaters/skaters19-20.csv")
skaters20_21 = pd.read_csv("rawData/skaters/skaters20-21.csv")
skaters21_22 = pd.read_csv("rawData/skaters/skaters21-22.csv")
skaters22_23 = pd.read_csv("rawData/skaters/skaters22-23.csv")
skaters23_24 = pd.read_csv("rawData/skaters/skaters23-24.csv")

#lines  - data consists

lines19_20 = pd.read_csv("rawData/lines/lines19-20.csv")
lines20_21 = pd.read_csv("rawData/lines/lines20-21.csv")
lines21_22 = pd.read_csv("rawData/lines/lines21-22.csv")
lines22_23 = pd.read_csv("rawData/lines/lines22-23.csv")
lines23_24 = pd.read_csv("rawData/lines/lines23-24.csv")

#teams 

teams19_20 = pd.read_csv("rawData/teams/teams19-20.csv")
teams20_21 = pd.read_csv("rawData/teams/teams20-21.csv")
teams21_22 = pd.read_csv("rawData/teams/teams21-22.csv")
teams22_23 = pd.read_csv("rawData/teams/teams22-23.csv")
teams23_24 = pd.read_csv("rawData/teams/teams23-24.csv")

# Player Information (DoB, Position, Handedness)

allPlayers = pd.read_csv("rawData/allPlayers.csv")

# %% [markdown]
# # Data Cleaning
# ### SKATERS

# %%
## Clean Column Names 

def clean_cols(data):

    data.columns = data.columns.str.replace(' ', '')

# %%
# Merge all 5 seasons together into one lovely dataset! 

allYears_skaters = [skaters19_20, skaters20_21, skaters21_22, skaters22_23, skaters23_24]

for df in allYears_skaters:
    clean_cols(df)
    
skaters = pd.concat(allYears_skaters, ignore_index=True)
skaters
# Out:
#        playerId  season          name team position situation  games_played  \
# 0       8475169    2019  Evander Kane  S.J        L     other            64
# 1       8475169    2019  Evander Kane  S.J        L       all            64
# 2       8475169    2019  Evander Kane  S.J        L      5on5            64
# 3       8475169    2019  Evander Kane  S.J        L      4on5            64
# 4       8475169    2019  Evander Kane  S.J        L      5on4            64
# ...         ...     ...           ...  ...      ...       ...           ...
# 23365   8477488    2023   Brett Pesce  CAR        D     other            70
# 23366   8477488    2023   Brett Pesce  CAR        D       all            70
# 23367   8477488    2023   Brett Pesce  CAR        D      5on5            70
# 23368   8477488    2023   Brett Pesce  CAR        D      4on5            70
# 23369   8477488    2023   Brett Pesce  CAR        D      5on4            70
#
#        icetime  shifts  gameScore  ...  OffIce_F_xGoals  OffIce_A_xGoals  \
# 0       3559.0    55.0      41.11  ...            11.88             7.62
# 1      74903.0  1518.0      46.28  ...           110.25           125.20
# 2      56312.0  1195.0      46.28  ...            88.72            88.15
# 3       5124.0   137.0      40.77  ...             3.23            23.36
# 4       9908.0   131.0      45.09  ...             5.67             1.21
# ...        ...     ...        ...  ...              ...              ...
# 23365   2731.0    48.0      30.97  ...            12.35            11.97
# 23366  85212.0  1725.0      41.27  ...           172.40           122.21
# 23367  72590.0  1415.0      41.27  ...           107.20            80.61
# 23368   9349.0   217.0      40.17  ...             3.63            19.19
# 23369    542.0    45.0      17.68  ...            20.66             2.17
#
#        OffIce_F_shotAttempts  OffIce_A_shotAttempts  xGoalsForAfterShifts  \
# 0                       77.0                  105.0                  0.00
# 1                     2254.0                 2440.0                  0.00
# 2                     1981.0                 1904.0                  2.03
# 3                       53.0                  358.0                  0.00
# 4                      131.0                   21.0                  0.00
# ...                      ...                    ...                   ...
# 23365                  125.0                   84.0                  0.04
# 23366                 3431.0                 2154.0                  0.00
# 23367                 2625.0                 1751.0                  4.63
# 23368                   63.0                  222.0                  0.45
# 23369                  303.0                   36.0                  0.00
#
#        xGoalsAgainstAfterShifts  corsiForAfterShifts  corsiAgainstAfterShifts  \
# 0                          0.07                  0.0                      2.0
# 1                          0.00                  0.0                      0.0
# 2                          1.24                 40.0                     37.0
# 3                          0.04                  0.0                      1.0
# 4                          0.34                  0.0                      4.0
# ...                         ...                  ...                      ...
# 23365                      0.00                  1.0                      0.0
# 23366                      0.00                  0.0                      0.0
# 23367                      0.35                115.0                     17.0
# 23368                      0.05                  7.0                      1.0
# 23369                      0.00                  0.0                      0.0
#
#        fenwickForAfterShifts  fenwickAgainstAfterShifts
# 0                        0.0                        2.0
# 1                        0.0                        0.0
# 2                       32.0                       31.0
# 3                        0.0                        1.0
# 4                        0.0                        4.0
# ...                      ...                        ...
# 23365                    1.0                        0.0
# 23366                    0.0                        0.0
# 23367                   89.0                       12.0
# 23368                    6.0                        1.0
# 23369                    0.0                        0.0
#
# [23370 rows x 154 columns]

# %%
# Identify Potential Incorrect Names in Data Set 
skaters_names = skaters.copy()
players_names = allPlayers.copy()

skaters_names['name'] = skaters['name'].str.lower()
players_names['name'] = allPlayers['name'].str.lower()

incorrect_names = skaters[~skaters['name'].isin(allPlayers['name'])].groupby(['name']).sum()
incorrect_names['playerId']
# Out:
# name
# Alex Barre-Boulet         84797180
# Alex Nylander             84794230
# Alex Wennberg            169550100
# Alexander Chmelevski      42400265
# Alexander Kerfoot        169540420
# Alexei Toropchenko        42401405
# Alexis Lafreniere         84821090
# Benoit-Olivier Groulx     84808700
# Christopher Tanev        127135350
# Gerald Mayhew             84799330
# Jacob Middleton          127172040
# Jani Hakanpaa            127137375
# Jesse Ylonen             127215870
# Marian Studenic          127203390
# Matt Dumba               211921400
# Max Comtois              212000775
# Maxime Lajoie            127189800
# Mitchell Marner          169569660
# Nicholas Abruzzese        42408600
# Nicholas Merkley          84784470
# Nick Paul                 84774260
# Samuel Walker             42401335
# Thomas Novak              42392190
# Tim Stutzle               84821160
# William Borgen            42394200
# Zach Sanford             169549640
# Name: playerId, dtype: int64

# %%
# Clean up Team Names so that they are all uniform 

def clean_teamName(df):
    # Replace all instances of "S.J" with "SJS" in column: 'team'
    df['team'] = df['team'].str.replace("S.J", "SJS", case=False, regex=False)
    # Replace all instances of "T.B" with "TBL" in column: 'team'
    df['team'] = df['team'].str.replace("T.B", "TBL", case=False, regex=False)
    # Replace all instances of "L.A" with "LAK" in column: 'team'
    df['team'] = df['team'].str.replace("L.A", "LAK", case=False, regex=False)
    # Replace all instances of "N.J" with "NJD" in column: 'team'
    df['team'] = df['team'].str.replace("N.J", "NJD", case=False, regex=False)
    return df

# %%
def fix_names(df):
    '''Fix player names in data frames '''

    df['name'] = df['name'].str.replace("Alex Nylander", "Alexander Nylander", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alexander Chmelevski", "Sasha Chmelevski", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alex Kerfoot", "Alexander Kerfoot", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alexis Lafrenire", "Alexis Lafreniere", case=False, regex=False)
    df['name'] = df['name'].str.replace("Tim Sttzle", "Tim Stutzle", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alex Barr-Boulet", "Alex Barre-Boulet", case=False, regex=False)
    df['name'] = df['name'].str.replace("Bo Groulx", "Benoit-Olivier Groulx", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alexander Wennberg", "Alex Wennberg", case=False, regex=False)
    df['name'] = df['name'].str.replace("Alexei Toropchenko", "Alexey Toropchenko", case=False, regex=False)
    df['name'] = df['name'].str.replace("Christopher Tanev", "Chris Tanev", case=False, regex=False)
    df['name'] = df['name'].str.replace("Gerald Mayhew", "Gerry Mayhew", case=False, regex=False)
    df['name'] = df['name'].str.replace("Jacob Middleton", "Jake Middleton", case=False, regex=False)
    df['name'] = df['name'].str.replace("Jani Hakanp", "Jani Hakanpaa", case=False, regex=False)
    df['name'] = df['name'].str.replace("Jani Hakanpaaaa", "Jani Hakanpaa", case=False, regex=False)
    df['name'] = df['name'].str.replace("Jesse Ylnen", "Jesse Ylonen", case=False, regex=False)
    df['name'] = df['name'].str.replace("Marin Studenic", "Marian Studenic", case=False, regex=False)
    df['name'] = df['name'].str.replace("Maxime Lajoie", "Max Lajoie", case=False, regex=False)
    df['name'] = df['name'].str.replace("Mitchell Marner", "Mitch Marner", case=False, regex=False)
    df['name'] = df['name'].str.replace("Nicholas Abruzzese", "Nick Abruzzese", case=False, regex=False)
    df['name'] = df['name'].str.replace("Nicholas Merkley", "Nick Merkley", case=False, regex=False)
    df['name'] = df['name'].str.replace("Nicholas Paul", "Nick Paul", case=False, regex=False)
    df['name'] = df['name'].str.replace("Samuel Walker", "Sammy Walker", case=False, regex=False)
    df['name'] = df['name'].str.replace("Thomas Novak", "Tommy Novak", case=False, regex=False)
    df['name'] = df['name'].str.replace("William Borgen", "Will Borgen", case=False, regex=False)
    df['name'] = df['name'].str.replace("Maxime Comtois", "Max Comtois", case=False, regex=False)
    df['name'] = df['name'].str.replace("Mathew Dumba", "Matt Dumba", case=False, regex=False)
    df['name'] = df['name'].str.replace("Zachary Sanford", "Zach Sanford", case=False, regex=False)
    return df

# %%
# CLEAN DATASETS 

allPlayers = clean_teamName(allPlayers)
allPlayers = fix_names(allPlayers)

skaters = clean_teamName(skaters)
skaters = fix_names(skaters)

allPlayers
# Out:
#       playerId               name position team   birthDate  weight  height  \
# 0      8478421         A.J. Greer        L  CGY  1996-12-14   210.0   6' 3"
# 1      8477180         Aaron Dell        G  SJS  1989-05-04   205.0   6' 0"
# 2      8465992       Aaron Downey        R  DET  1974-08-27   215.0   6' 1"
# 3      8477932       Aaron Ekblad        D  FLA  1996-02-07   220.0   6' 4"
# 4      8471451       Aaron Gagnon        C  WPG  1986-04-24   186.0  5' 11"
# ...        ...                ...      ...  ...         ...     ...     ...
# 3149   8475876      Zane McIntyre        G  BOS  1992-08-20   206.0   6' 2"
# 3150   8469760    Zbynek Michalek        D  ARI  1982-12-23   210.0   6' 2"
# 3151   8465009        Zdeno Chara        D  NYI  1977-03-18   250.0   6' 9"
# 3152   8476878  Zemgus Girgensons        L  BUF  1994-01-05   211.0   6' 2"
# 3153   8469820      Zenon Konopka        C  BUF  1981-01-02   213.0   6' 0"
#
#      nationality shootsCatches  primaryNumber primaryPosition
# 0            CAN             L           24.0               L
# 1            CAN             L           30.0               G
# 2            CAN             R           44.0               R
# 3            CAN             R            5.0               D
# 4            CAN             R           21.0               C
# ...          ...           ...            ...             ...
# 3149         USA             L           31.0               G
# 3150         CZE             R            4.0               D
# 3151         SVK             L           33.0               D
# 3152         LVA             L           28.0               C
# 3153         CAN             L           24.0               C
#
# [3154 rows x 11 columns]

# %%
# Extract only the stats for 5on5 (could look into special teams later )

fullStrength = skaters[skaters['situation'] == '5on5']

fullStrength = fullStrength.sort_values(['team', 'name'])
fullStrength
# Out:
#        playerId  season                 name team position situation  \
# 2322    8474641    2019        Adam Henrique  ANA        C      5on5
# 6012    8474641    2020        Adam Henrique  ANA        C      5on5
# 10752   8474641    2021        Adam Henrique  ANA        C      5on5
# 14047   8474641    2022        Adam Henrique  ANA        C      5on5
# 19842   8473986    2023         Alex Killorn  ANA        L      5on5
# ...         ...     ...                  ...  ...      ...       ...
# 19622   8477845    2023  Trevor van Riemsdyk  WSH        D      5on5
# 3282    8477343    2019      Tyler Lewington  WSH        D      5on5
# 17592   8482861    2022        Vincent Iorio  WSH        D      5on5
# 22037   8482861    2023        Vincent Iorio  WSH        D      5on5
# 6457    8465009    2020          Zdeno Chara  WSH        D      5on5
#
#        games_played  icetime  shifts  gameScore  ...  OffIce_F_xGoals  \
# 2322             71  55793.0  1275.0      48.82  ...            89.98
# 6012             45  34324.0   777.0      22.62  ...            55.77
# 10752            58  50470.0  1101.0      43.53  ...            72.98
# 14047            62  47265.0  1069.0      32.10  ...            78.19
# 19842            63  54790.0  1071.0      35.97  ...            74.08
# ...             ...      ...     ...        ...  ...              ...
# 19622            70  69882.0  1400.0      11.57  ...            90.18
# 3282              6   3536.0    78.0      -0.30  ...             8.32
# 17592             3   2443.0    67.0       0.27  ...             3.20
# 22037             6   3537.0    83.0       0.35  ...             9.87
# 6457             55  49078.0   994.0      13.48  ...            72.65
#
#        OffIce_A_xGoals  OffIce_F_shotAttempts  OffIce_A_shotAttempts  \
# 2322            102.05                 2216.0                 2489.0
# 6012             69.11                 1374.0                 1536.0
# 10752            83.27                 1717.0                 1994.0
# 14047           128.08                 1863.0                 2538.0
# 19842            88.70                 1711.0                 2096.0
# ...                ...                    ...                    ...
# 19622           104.72                 2117.0                 2398.0
# 3282              9.13                  217.0                  232.0
# 17592             6.81                   79.0                  108.0
# 22037             8.46                  259.0                  260.0
# 6457             69.12                 1682.0                 1616.0
#
#        xGoalsForAfterShifts  xGoalsAgainstAfterShifts  corsiForAfterShifts  \
# 2322                   2.11                      1.39                 47.0
# 6012                   1.39                      0.62                 30.0
# 10752                  1.79                      1.48                 36.0
# 14047                  1.61                      1.00                 38.0
# 19842                  1.12                      1.82                 18.0
# ...                     ...                       ...                  ...
# 19622                  5.45                      1.64                128.0
# 3282                   0.44                      0.00                  7.0
# 17592                  0.04                      0.00                  3.0
# 22037                  0.11                      0.02                  6.0
# 6457                   1.89                      1.36                 40.0
#
#        corsiAgainstAfterShifts  fenwickForAfterShifts  \
# 2322                      34.0                   34.0
# 6012                      18.0                   24.0
# 10752                     31.0                   28.0
# 14047                     18.0                   31.0
# 19842                     37.0                   16.0
# ...                        ...                    ...
# 19622                     27.0                   97.0
# 3282                       0.0                    6.0
# 17592                      0.0                    2.0
# 22037                      2.0                    5.0
# 6457                      14.0                   34.0
#
#        fenwickAgainstAfterShifts
# 2322                        25.0
# 6012                        11.0
# 10752                       26.0
# 14047                       14.0
# 19842                       30.0
# ...                          ...
# 19622                       19.0
# 3282                         0.0
# 17592                        0.0
# 22037                        2.0
# 6457                        13.0
#
# [4674 rows x 154 columns]

# %% [markdown]
# ### LINES

# %%
# Create dataset for all lines/dpairings utilised during past 5 seasons 

lines = pd.concat([lines19_20, lines20_21, lines21_22, lines22_23, lines23_24], ignore_index=True)

clean_cols(lines)
clean_teamName(lines)
lines = lines.sort_values('team')
lines
# Out:
#                       lineId  season                  name team position  \
# 1934          84735608478425    2019          Guhle-Holzer  ANA  pairing
# 11505         84809508482803    2023  Lyubushkin-Zellweger  ANA  pairing
# 11507         84828038483490    2023   Mintyukov-Zellweger  ANA  pairing
# 4947          84811228482142    2021       Benoit-Drysdale  ANA  pairing
# 4949          84768548479372    2021       Lindholm-Mahura  ANA  pairing
# ...                      ...     ...                   ...  ...      ...
# 140    847418984768808477944    2019    Vrana-Eller-Wilson  WSH     line
# 4709   847169884741898477839    2020    Sheary-Eller-Oshie  WSH     line
# 876           84754628480796    2019       Fehervary-Gudas  WSH  pairing
# 3733   847418984772908477839    2020    Raffl-Eller-Sheary  WSH     line
# 10201         84745908477845    2022  Carlson-Van Riemsdyk  WSH  pairing
#
#       situation  games_played  icetime  iceTimeRank  xGoalsPercentage  ...  \
# 1934       5on5            18   8673.0         79.0              0.40  ...
# 11505      5on5             1    638.0          3.0              0.12  ...
# 11507      5on5            13    876.0        102.0              0.76  ...
# 4947       5on5            24    863.0        189.0              0.32  ...
# 4949       5on5            10    660.0         62.0              0.88  ...
# ...         ...           ...      ...          ...               ...  ...
# 140        5on5            34   1802.0        339.0              0.73  ...
# 4709       5on5             7   1151.0         74.0              0.52  ...
# 876        5on5             4   2377.0         12.0              0.55  ...
# 3733       5on5             8   4256.0         28.0              0.63  ...
# 10201      5on5            19   1090.0        158.0              0.26  ...
#
#        scoreAdjustedShotsAttemptsAgainst  unblockedShotAttemptsAgainst  \
# 1934                              133.11                          92.0
# 11505                              13.96                          11.0
# 11507                               9.53                           7.0
# 4947                               31.29                          20.0
# 4949                                2.15                           2.0
# ...                                  ...                           ...
# 140                                16.45                          13.0
# 4709                               22.87                          19.0
# 876                                28.05                          23.0
# 3733                               44.50                          34.0
# 10201                              16.39                          13.0
#
#        scoreAdjustedUnblockedShotAttemptsAgainst  dZoneGiveawaysAgainst  \
# 1934                                       91.68                   14.0
# 11505                                      10.62                    0.0
# 11507                                       7.34                    0.0
# 4947                                       20.95                    1.0
# 4949                                        2.12                    0.0
# ...                                          ...                    ...
# 140                                        12.67                    4.0
# 4709                                       18.71                    1.0
# 876                                        23.23                    5.0
# 3733                                       32.88                    5.0
# 10201                                      12.61                    2.0
#
#        xGoalsFromxReboundsOfShotsAgainst  \
# 1934                                0.89
# 11505                               0.11
# 11507                               0.06
# 4947                                0.19
# 4949                                0.01
# ...                                  ...
# 140                                 0.13
# 4709                                0.18
# 876                                 0.21
# 3733                                0.36
# 10201                               0.12
#
#        xGoalsFromActualReboundsOfShotsAgainst  reboundxGoalsAgainst  \
# 1934                                     0.93                  0.93
# 11505                                    0.00                  0.00
# 11507                                    0.00                  0.00
# 4947                                     0.48                  0.48
# 4949                                     0.00                  0.00
# ...                                       ...                   ...
# 140                                      0.16                  0.16
# 4709                                     0.14                  0.14
# 876                                      0.00                  0.00
# 3733                                     0.52                  0.52
# 10201                                    0.52                  0.52
#
#        totalShotCreditAgainst  scoreAdjustedTotalShotCreditAgainst  \
# 1934                     4.48                                 4.52
# 11505                    1.03                                 1.02
# 11507                    0.34                                 0.34
# 4947                     1.18                                 1.24
# 4949                     0.06                                 0.06
# ...                       ...                                  ...
# 140                      0.68                                 0.64
# 4709                     1.02                                 0.98
# 876                      1.45                                 1.46
# 3733                     1.99                                 1.94
# 10201                    0.75                                 0.72
#
#        scoreFlurryAdjustedTotalShotCreditAgainst
# 1934                                        4.45
# 11505                                       1.01
# 11507                                       0.34
# 4947                                        1.22
# 4949                                        0.06
# ...                                          ...
# 140                                         0.64
# 4709                                        0.94
# 876                                         1.43
# 3733                                        1.91
# 10201                                       0.72
#
# [14030 rows x 108 columns]

# %% [markdown]
# ### TEAMS

# %%
correct_headers = teams19_20.columns

# Move the current headers (first row of df1) to be the first row of the data

teams22_23.loc[-1] = teams22_23.columns  # Add the headers as the first row
teams22_23.index = teams22_23.index + 1  # Shift index
teams22_23 = teams22_23.sort_index()
teams22_23.columns = correct_headers


allTeams = [teams19_20, teams20_21, teams21_22, teams22_23, teams23_24]

for team in allTeams:
    clean_cols(team)

teams = pd.concat(allTeams, ignore_index=True)

clean_cols(teams)
clean_teamName(teams)
teams = teams.sort_values('team')
teams
# Out:
#     team season name team.1    position situation games_played  \
# 169  ANA   2020  ANA    ANA  Team Level      5on4           56
# 414  ANA   2021  ANA    ANA  Team Level      5on4           82
# 719  ANA   2023  ANA    ANA  Team Level      5on4           82
# 70   ANA   2019  ANA    ANA  Team Level     other           71
# 71   ANA   2019  ANA    ANA  Team Level       all           71
# ..   ...    ...  ...    ...         ...       ...          ...
# 183  WSH   2020  WSH    WSH  Team Level      4on5           56
# 184  WSH   2020  WSH    WSH  Team Level      5on4           56
# 439  WSH   2021  WSH    WSH  Team Level      5on4           82
# 437  WSH   2021  WSH    WSH  Team Level      5on5           82
# 438  WSH   2021  WSH    WSH  Team Level      4on5           82
#
#     xGoalsPercentage corsiPercentage fenwickPercentage  ...  \
# 169             0.86            0.87              0.85  ...
# 414             0.87            0.86              0.82  ...
# 719             0.86            0.88              0.86  ...
# 70               0.5            0.45              0.46  ...
# 71              0.47            0.49              0.49  ...
# ..               ...             ...               ...  ...
# 183             0.15            0.13              0.15  ...
# 184             0.89            0.88              0.87  ...
# 439             0.89            0.84              0.82  ...
# 437              0.5            0.51              0.51  ...
# 438             0.15            0.15              0.16  ...
#
#     scoreAdjustedShotsAttemptsAgainst unblockedShotAttemptsAgainst  \
# 169                              47.0                           44
# 414                              93.0                         84.0
# 719                              77.0                         64.0
# 70                              235.0                        182.0
# 71                            4117.05                       3158.0
# ..                                ...                          ...
# 183                             379.0                          287
# 184                              52.0                           46
# 439                             117.0                        104.0
# 437                           3589.82                       2655.0
# 438                             511.0                        387.0
#
#     scoreAdjustedUnblockedShotAttemptsAgainst dZoneGiveawaysAgainst  \
# 169                                      44.0                    22
# 414                                      84.0                  36.0
# 719                                      64.0                  22.0
# 70                                      182.0                   7.0
# 71                                     3170.3                 417.0
# ..                                        ...                   ...
# 183                                     287.0                     2
# 184                                      46.0                    20
# 439                                     104.0                  34.0
# 437                                   2656.89                 362.0
# 438                                     387.0                  10.0
#
#     xGoalsFromxReboundsOfShotsAgainst xGoalsFromActualReboundsOfShotsAgainst  \
# 169                              0.38                                   0.44
# 414                              0.69                                    0.0
# 719                              0.59                                   0.66
# 70                               2.67                                   1.77
# 71                              33.44                                  34.92
# ..                                ...                                    ...
# 183                              5.06                                   4.61
# 184                              0.38                                    0.0
# 439                              0.84                                   0.66
# 437                             26.61                                  31.68
# 438                              6.73                                   7.04
#
#     reboundxGoalsAgainst totalShotCreditAgainst  \
# 169                 0.44                   2.87
# 414                  0.0                   5.63
# 719                 0.66                   5.69
# 70                  1.77                  22.65
# 71                  35.0                 195.42
# ..                   ...                    ...
# 183                 4.61                  24.68
# 184                  0.0                   3.04
# 439                 0.62                   5.92
# 437                32.07                  150.5
# 438                 7.04                  33.76
#
#     scoreAdjustedTotalShotCreditAgainst  \
# 169                                2.87
# 414                                5.63
# 719                                5.69
# 70                                22.65
# 71                               196.28
# ..                                  ...
# 183                               24.68
# 184                                3.04
# 439                                5.92
# 437                              150.13
# 438                               33.76
#
#     scoreFlurryAdjustedTotalShotCreditAgainst
# 169                                      2.86
# 414                                      5.59
# 719                                      5.67
# 70                                      22.27
# 71                                     192.41
# ..                                        ...
# 183                                     23.65
# 184                                      3.03
# 439                                       5.9
# 437                                    147.88
# 438                                     31.15
#
# [790 rows x 107 columns]

# %% [markdown]
# # Data Processing

# %%
# LINES 

forwardLines = lines[lines['position'] == 'line']
dpairings = lines[lines['position'] == 'pairing']

forwardLines.columns
# Out:
# Index(['lineId', 'season', 'name', 'team', 'position', 'situation',
#        'games_played', 'icetime', 'iceTimeRank', 'xGoalsPercentage',
#        ...
#        'scoreAdjustedShotsAttemptsAgainst', 'unblockedShotAttemptsAgainst',
#        'scoreAdjustedUnblockedShotAttemptsAgainst', 'dZoneGiveawaysAgainst',
#        'xGoalsFromxReboundsOfShotsAgainst',
#        'xGoalsFromActualReboundsOfShotsAgainst', 'reboundxGoalsAgainst',
#        'totalShotCreditAgainst', 'scoreAdjustedTotalShotCreditAgainst',
#        'scoreFlurryAdjustedTotalShotCreditAgainst'],
#       dtype='object', length=108)

# %%
fiveOnFive = pd.merge(fullStrength, allPlayers, on=['playerId', 'name', 'position'])
fiveOnFive = fiveOnFive.drop(columns={'team_y', 'primaryPosition'}).rename(columns={'team_x': 'team'})
fiveOnFive
# Out:
#       playerId  season                 name team position situation  \
# 0      8474641    2019        Adam Henrique  ANA        C      5on5
# 1      8474641    2020        Adam Henrique  ANA        C      5on5
# 2      8474641    2021        Adam Henrique  ANA        C      5on5
# 3      8474641    2022        Adam Henrique  ANA        C      5on5
# 4      8473986    2023         Alex Killorn  ANA        L      5on5
# ...        ...     ...                  ...  ...      ...       ...
# 4552   8477845    2023  Trevor van Riemsdyk  WSH        D      5on5
# 4553   8477343    2019      Tyler Lewington  WSH        D      5on5
# 4554   8482861    2022        Vincent Iorio  WSH        D      5on5
# 4555   8482861    2023        Vincent Iorio  WSH        D      5on5
# 4556   8465009    2020          Zdeno Chara  WSH        D      5on5
#
#       games_played  icetime  shifts  gameScore  ...  corsiForAfterShifts  \
# 0               71  55793.0  1275.0      48.82  ...                 47.0
# 1               45  34324.0   777.0      22.62  ...                 30.0
# 2               58  50470.0  1101.0      43.53  ...                 36.0
# 3               62  47265.0  1069.0      32.10  ...                 38.0
# 4               63  54790.0  1071.0      35.97  ...                 18.0
# ...            ...      ...     ...        ...  ...                  ...
# 4552            70  69882.0  1400.0      11.57  ...                128.0
# 4553             6   3536.0    78.0      -0.30  ...                  7.0
# 4554             3   2443.0    67.0       0.27  ...                  3.0
# 4555             6   3537.0    83.0       0.35  ...                  6.0
# 4556            55  49078.0   994.0      13.48  ...                 40.0
#
#       corsiAgainstAfterShifts  fenwickForAfterShifts  \
# 0                        34.0                   34.0
# 1                        18.0                   24.0
# 2                        31.0                   28.0
# 3                        18.0                   31.0
# 4                        37.0                   16.0
# ...                       ...                    ...
# 4552                     27.0                   97.0
# 4553                      0.0                    6.0
# 4554                      0.0                    2.0
# 4555                      2.0                    5.0
# 4556                     14.0                   34.0
#
#       fenwickAgainstAfterShifts   birthDate  weight  height  nationality  \
# 0                          25.0  1990-02-06   197.0   6' 0"          CAN
# 1                          11.0  1990-02-06   197.0   6' 0"          CAN
# 2                          26.0  1990-02-06   197.0   6' 0"          CAN
# 3                          14.0  1990-02-06   197.0   6' 0"          CAN
# 4                          30.0  1989-09-14   196.0   6' 1"          CAN
# ...                         ...         ...     ...     ...          ...
# 4552                       19.0  1991-07-24   192.0   6' 2"          USA
# 4553                        0.0  1994-12-05   202.0   6' 2"          CAN
# 4554                        0.0  2002-11-14   200.0   6' 4"          CAN
# 4555                        2.0  2002-11-14   200.0   6' 4"          CAN
# 4556                       13.0  1977-03-18   250.0   6' 9"          SVK
#
#       shootsCatches  primaryNumber
# 0                 L           14.0
# 1                 L           14.0
# 2                 L           14.0
# 3                 L           14.0
# 4                 L           17.0
# ...             ...            ...
# 4552              R           57.0
# 4553              R           78.0
# 4554              R            6.0
# 4555              R            6.0
# 4556              L           33.0
#
# [4557 rows x 160 columns]

# %%
# Divide the forwards and defencemen into 2 different dataframes. We don't want D-men when we are predicting our lines. 

forwards55 = fiveOnFive[fiveOnFive['position'].isin(['L', 'C', 'R'])]
defense55 = fiveOnFive[fiveOnFive['position'] == 'D']

# %% [markdown]
# # Exploratory Analysis - What factors lead to the most optimal lines?
#
# To help us identify, what factors lead to the most optimal lines, we should look subjectively to what are the best lines in the NHL. Of course if you ask anyone, there will always be different opinions so I have taken into account 3 different websites to see what they thought the best lines of the 2022-23 season were. Stats that were generally used to determine these lines this were Goals Percentage (Goal%) and expected goals percentage (xGoals%), along with minutes played, actual goals for and against as well as expected goals for and against.
#
# ESPN: https://www.espn.com.au/nhl/insider/insider/story/_/id/35204274/ranking-best-lines-nhl-2022-23-season
#
# 1. Dallas Stars: Jason Robertson-Roope Hintz-Joe Pavelski
# 2. Boston Bruins: Brad Marchand-Patrice Bergeron-Jake Debrusk
# 3. Vegas Golden Knights: Chandler Stephenson-Jack Eichel-Mark Stone
# 4. Florida Panthers: Carter Verhaeghe-Aleksander Barkov-Matthew Tkachuk
# 5. New Jersey Devils: Fabian Zetterland-Nico Hischier-Tomas Tatar
#
# The Hockey Writers: https://thehockeywriters.com/nhl-top-5-forward-lines-2022-23/
#
# 1. Calgary Flames: Andrew Mangiapane-Mikael Backlund-Blake Coleman
# 2. Boston Bruins: Brad Marchand-Patrice Bergeron-Jake Debrusk
# 3. Toronto Maple Leafs: Michael Bunting-Auston Matthews-William Nylander
# 4. Dallas Stars: Jason Robertson-Roope Hintz-Joe Pavelski
# 5. LA Kings: Quinton Byfield-Anze Kopitar-Adrian Kempe
#
# Bleacher Report: https://bleacherreport.com/articles/10053471-ranking-the-top-15-best-forward-lines-early-in-the-2022-23-nhl-season
#
# 1. Carolina Hurricanes: Andrei Svechnikov-Matin Necas-Jesper Kotkaniemi
# 2. Dallas Stars: Jason Robertson-Roope Hintz-Joe Pavelski
# 3. Pittsburgh Penguins: Jake Guentzel-Sidney Crosby-Rickard Rakell
# 4. Boston Bruins: Taylor Hall-David Krejci-David Pastrnak
# 5. Toronto Maple Leafs: Michael Bunting-Auston Matthews-Mitch Marner
#
# https://bleacherreport.com/articles/10095790-ranking-the-nhls-top-5-lines-for-the-2023-24-season
#
# 1. Dallas Stars: Jason Robertson-Roope Hintz-Joe Pavelski
# 2. Edmonton Oilers: Leon Draisatl-Connor McDavid-Zach Hyman
# 3. LA Kings: Quinton Byfield-Anze Kopitar-Adrian Kempe
# 4. Ottawa Senators: Brady Tkachuk-Tim Stutzle-Claude Giroux
# 5. Pittsburgh Penguins: Jake Guentzel-Sidney Crosby-Bryan Rust
#
# Sportskeeda: https://www.sportskeeda.com/us/nhl/ranking-top-5-forward-lines-2024-nhl-season
#
# 1. Florida Panthers: Sam Reinhart-Aleksander Barkov-Evan Rodriguez
# 2. Dallas Stars: Mason Marchment-Tyler Seguin-Matt Duchene
# 3. Vancouver Canucks: Dakota Joshua-Teddy Blueger-Connor Garland
# 4. Calgary Flames: Connor Zary-Nazem Kadri-Martin Pospisil
# 5. LA Kings: Quinton Byfield-Anze Kopitar-Adrian Kempe

# %%
forwardLines = forwardLines[['lineId', 'season', 'name', 'team', 'games_played', 'icetime', 'xGoalsPercentage',
                  'xGoalsFor', 'xGoalsAgainst', 'shotsOnGoalFor', 'shotsOnGoalAgainst', 'goalsFor', 'goalsAgainst', 'penaltiesFor', 
                   'penaltiesAgainst', 'faceOffsWonFor', 'hitsFor']]

forwardLines.head()
# Out:
#                       lineId  season                              name team  \
# 454    847464184751648479368    2019        Jones-Henrique-Silfverberg  ANA
# 3339   847061284788738480186    2020              Terry-Getzlaf-Volkov  ANA
# 2571   847464184780468478873    2020             Heinen-Henrique-Terry  ANA
# 11519  847516484808068482118    2023  Colangelo-Lundestrom-Silfverberg  ANA
# 9085   847836684815178482745    2022           Vatrano-Mctavish-Leason  ANA
#
#        games_played  icetime  xGoalsPercentage  xGoalsFor  xGoalsAgainst  \
# 454              16   3458.0              0.47       1.42           1.60
# 3339              4    935.0              0.31       0.42           0.94
# 2571              6    709.0              0.60       0.54           0.36
# 11519             2   1031.0              0.41       0.77           1.09
# 9085             15   2032.0              0.32       0.95           2.05
#
#        shotsOnGoalFor  shotsOnGoalAgainst  goalsFor  goalsAgainst  \
# 454              21.0                30.0       1.0           4.0
# 3339              7.0                10.0       0.0           2.0
# 2571              5.0                 5.0       0.0           1.0
# 11519             9.0                 6.0       1.0           1.0
# 9085              9.0                25.0       0.0           4.0
#
#        penaltiesFor  penaltiesAgainst  faceOffsWonFor  hitsFor
# 454             2.0               5.0            29.0     14.0
# 3339            2.0               3.0             9.0      5.0
# 2571            1.0               1.0             3.0      6.0
# 11519           2.0               1.0            10.0      7.0
# 9085            4.0               4.0            11.0      9.0

# %%
forwardsSortedIceTime = forwardLines.sort_values(by=['icetime'], ascending=False)
forwardsSortedIceTime
# Out:
#                       lineId  season                        name team  \
# 7282   847634684774968479314    2021   Gaudreau-Lindholm-Tkachuk  CGY
# 12284  847638984785508482109    2023  Lafrenire-Trocheck-Panarin  NYR
# 6778   847079484784498480027    2021    Robertson-Hintz-Pavelski  DAL
# 12014  847467984751588476887    2023   Forsberg-O'Reilly-Nyquist  NSH
# 8661   847079484784498480027    2022    Robertson-Pavelski-Hintz  DAL
# ...                      ...     ...                         ...  ...
# 11449  847531484784458481601    2023        Lee-Barzal-Holmstrom  NYI
# 493    847123384751518479407    2019        Bratt-Zajac-Palmieri  NJD
# 3777   847405384751698478414    2020          Kane-Couture-Meier  SJS
# 12123  847341984757458478409    2023      Marchand-Coyle-Richard  BOS
# 9805   847181784778468478211    2022       Hunt-Carpenter-Reaves  NYR
#
#        games_played  icetime  xGoalsPercentage  xGoalsFor  xGoalsAgainst  \
# 7282             82  57915.0              0.62      54.06          32.86
# 12284            74  51785.0              0.56      45.04          35.89
# 6778             72  47465.0              0.59      43.29          29.47
# 12014            78  45988.0              0.55      39.90          33.30
# 8661             73  45886.0              0.59      41.04          28.28
# ...             ...      ...               ...        ...            ...
# 11449             3    600.0              0.58       0.18           0.13
# 493               5    600.0              0.70       0.34           0.15
# 3777             19    600.0              0.09       0.05           0.52
# 12123             4    600.0              0.21       0.33           1.28
# 9805              2    600.0              0.05       0.02           0.43
#
#        shotsOnGoalFor  shotsOnGoalAgainst  goalsFor  goalsAgainst  \
# 7282            584.0               439.0      72.0          31.0
# 12284           530.0               416.0      54.0          39.0
# 6778            473.0               381.0      51.0          35.0
# 12014           453.0               394.0      46.0          31.0
# 8661            436.0               344.0      52.0          24.0
# ...               ...                 ...       ...           ...
# 11449             7.0                 3.0       0.0           0.0
# 493               5.0                 4.0       1.0           0.0
# 3777              4.0                 8.0       1.0           2.0
# 12123             6.0                 6.0       0.0           1.0
# 9805              2.0                 4.0       0.0           2.0
#
#        penaltiesFor  penaltiesAgainst  faceOffsWonFor  hitsFor
# 7282           50.0              60.0           552.0    230.0
# 12284          53.0              57.0           358.0    318.0
# 6778           28.0              34.0           473.0    244.0
# 12014          47.0              51.0           512.0    259.0
# 8661           30.0              51.0           472.0    229.0
# ...             ...               ...             ...      ...
# 11449           0.0               1.0             5.0      3.0
# 493             1.0               0.0             6.0      6.0
# 3777            3.0               1.0             2.0      5.0
# 12123           0.0               0.0             5.0      4.0
# 9805            1.0               2.0             3.0     18.0
#
# [9373 rows x 17 columns]

# %%
weights = {
    'icetimeMins': 0.2,
    'normalised_games_played': 0.15,
    'xGoalsPercentage': 0.6, 
    'xGoalsFor': 0.35, 
    'xGoalsAgainst': -0.35,
    'shotsOnGoalFor': 0.2,
    'shotsOnGoalAgainst': -0.2,  # Negative weight for shots against
    'goalsFor': 0.25,
    'goalsAgainst': -0.25,  # Negative weight for goals against
    'penaltiesFor': 0.01,  # Negative weight for penalties (you might want to penalize these) # Negative weight for penalty minutes
    'penaltiesAgainst': -0.01,  
    'faceOffsWonFor': 0.15,
    'hitsFor': 0.05
}

metrics = ['xGoalsFor', 
    'xGoalsAgainst',
    'shotsOnGoalFor',
    'shotsOnGoalAgainst',  # Negative weight for shots against
    'goalsFor',
    'goalsAgainst',  # Negative weight for goals against
    'penaltiesFor',  # Negative weight for penalties (you might want to penalize these) # Negative weight for penalty minutes
    'penaltiesAgainst',  
    'faceOffsWonFor',
    'hitsFor']

# Normalise metrics so that they represent the stat/60 minutes of icetime played 

forwardLines['icetimeMins'] = forwardLines['icetime']/60

normalised = forwardLines.copy()
for metric in metrics:
    normalised[metric] = (forwardLines[metric] / forwardLines['icetimeMins']) * 60
    
# Define the actual games played in each season
season_lengths = {
    2019: 70,
    2020: 56,
    2021: 82,
    2022: 82,
    2023: 82
}

# Normalize games_played by scaling to an 82-game season
normalised['normalised_games_played'] = normalised.apply(
    lambda row: row['games_played'] * (82 / season_lengths[row['season']]),
    axis=1
)

    
normalised = normalised.sort_values(by=['icetimeMins'], ascending=False)
normalised['name'] = normalised['name'].str.replace(' ', '')

normalised.head()
# Out:
#                       lineId  season                        name team  \
# 7282   847634684774968479314    2021   Gaudreau-Lindholm-Tkachuk  CGY
# 12284  847638984785508482109    2023  Lafrenire-Trocheck-Panarin  NYR
# 6778   847079484784498480027    2021    Robertson-Hintz-Pavelski  DAL
# 12014  847467984751588476887    2023   Forsberg-O'Reilly-Nyquist  NSH
# 8661   847079484784498480027    2022    Robertson-Pavelski-Hintz  DAL
#
#        games_played  icetime  xGoalsPercentage  xGoalsFor  xGoalsAgainst  \
# 7282             82  57915.0              0.62   3.360373       2.042580
# 12284            74  51785.0              0.56   3.131100       2.495008
# 6778             72  47465.0              0.59   3.283346       2.235163
# 12014            78  45988.0              0.55   3.123424       2.606767
# 8661             73  45886.0              0.59   3.219806       2.218716
#
#        shotsOnGoalFor  shotsOnGoalAgainst  goalsFor  goalsAgainst  \
# 7282        36.301476           27.288267  4.475524      1.926962
# 12284       36.844646           28.919571  3.753983      2.711210
# 6778        35.874855           28.897082  3.868113      2.654588
# 12014       35.461425           30.842829  3.600939      2.426720
# 8661        34.206512           26.988624  4.079676      1.882927
#
#        penaltiesFor  penaltiesAgainst  faceOffsWonFor    hitsFor  icetimeMins  \
# 7282       3.108003          3.729604       34.312354  14.296814   965.250000
# 12284      3.684465          3.962537       24.887516  22.106788   863.083333
# 6778       2.123670          2.578742       35.874855  18.506268   791.083333
# 12014      3.679221          3.992346       40.080021  20.274854   766.466667
# 8661       2.353659          4.001220       37.030903  17.966264   764.766667
#
#        normalised_games_played
# 7282                      82.0
# 12284                     74.0
# 6778                      72.0
# 12014                     78.0
# 8661                      73.0

# %%
normalised['line_score'] = normalised[weights.keys()].dot(pd.Series(weights))
bestLines = normalised.sort_values(by=['line_score'], ascending=False)

bestLines['rank'] = range(1, len(bestLines) + 1)
bestLines
# Out:
#                       lineId  season                        name team  \
# 7282   847634684774968479314    2021   Gaudreau-Lindholm-Tkachuk  CGY
# 12284  847638984785508482109    2023  Lafrenire-Trocheck-Panarin  NYR
# 6778   847079484784498480027    2021    Robertson-Hintz-Pavelski  DAL
# 12014  847467984751588476887    2023   Forsberg-O'Reilly-Nyquist  NSH
# 8661   847079484784498480027    2022    Robertson-Pavelski-Hintz  DAL
# ...                      ...     ...                         ...  ...
# 8796   847354884784038481032    2022        Cotter-Eichel-Kessel  VGK
# 10376  847735784783988479400    2022    Connor-Dubois-Maenalanen  WPG
# 10112  847398684745648476453    2022    Killorn-Stamkos-Kucherov  TBL
# 4783   847354884779518479465    2020    Caggiula-Schmaltz-Kessel  ARI
# 7654   847471584784398480797    2021    Atkinson-Farabee-Konecny  PHI
#
#        games_played  icetime  xGoalsPercentage  xGoalsFor  xGoalsAgainst  \
# 7282             82  57915.0              0.62   3.360373       2.042580
# 12284            74  51785.0              0.56   3.131100       2.495008
# 6778             72  47465.0              0.59   3.283346       2.235163
# 12014            78  45988.0              0.55   3.123424       2.606767
# 8661             73  45886.0              0.59   3.219806       2.218716
# ...             ...      ...               ...        ...            ...
# 8796             19    644.0              0.05   0.279503       5.086957
# 10376             8    639.0              0.11   0.901408       7.323944
# 10112             8    724.0              0.10   0.895028       8.154696
# 4783              7    773.0              0.11   0.652005       5.216041
# 7654              1    601.0              0.04   0.299501       6.589018
#
#        shotsOnGoalFor  ...  goalsFor  goalsAgainst  penaltiesFor  \
# 7282        36.301476  ...  4.475524      1.926962      3.108003
# 12284       36.844646  ...  3.753983      2.711210      3.684465
# 6778        35.874855  ...  3.868113      2.654588      2.123670
# 12014       35.461425  ...  3.600939      2.426720      3.679221
# 8661        34.206512  ...  4.079676      1.882927      2.353659
# ...               ...  ...       ...           ...           ...
# 8796         0.000000  ...  0.000000     11.180124      0.000000
# 10376        5.633803  ...  0.000000     11.267606      0.000000
# 10112        9.944751  ...  4.972376     19.889503      9.944751
# 4783        18.628719  ...  0.000000     13.971539      0.000000
# 7654        11.980033  ...  0.000000     11.980033      0.000000
#
#        penaltiesAgainst  faceOffsWonFor    hitsFor  icetimeMins  \
# 7282           3.729604       34.312354  14.296814   965.250000
# 12284          3.962537       24.887516  22.106788   863.083333
# 6778           2.578742       35.874855  18.506268   791.083333
# 12014          3.992346       40.080021  20.274854   766.466667
# 8661           4.001220       37.030903  17.966264   764.766667
# ...                 ...             ...        ...          ...
# 8796           0.000000        0.000000  50.310559    10.733333
# 10376          5.633803       16.901408  22.535211    10.650000
# 10112          0.000000       24.861878  19.889503    12.066667
# 4783           0.000000        4.657180  23.285899    12.883333
# 7654           0.000000       17.970050  29.950083    10.016667
#
#        normalised_games_played  line_score  rank
# 7282                     82.00  214.478488     1
# 12284                    74.00  190.956693     2
# 6778                     72.00  177.738458     3
# 12014                    78.00  173.744052     4
# 8661                     73.00  173.036952     5
# ...                        ...         ...   ...
# 8796                     19.00   -9.233582  9369
# 10376                     8.00   -9.330761  9370
# 10112                     8.00  -10.701805  9371
# 4783                     10.25  -11.155926  9372
# 7654                      1.00  -12.004031  9373
#
# [9373 rows x 21 columns]

# %%
best = ['Robertson-Pavelski-Hintz', 'Marchand-Bergeron-Debrusk','Stephenson-Eichel-Stone',
             'Tkachuk-Barkov-Verhaeghe', 'Tatar-Hischier-Zetterlund', 'Mangiapane-Backlund-Coleman', 'Debrusk-Bergeron-Marchand',
             'Bunting-Matthews-Nylander', 'Byfield-Kopitar-Kempe', 'Necas-Kotkaniemi-Svechnikov', 'Guentzel-Crosby-Rakell', 
             'Hall-Krejci-Pastrnak', 'Bunting-Matthews-Marner', 'Tkachuk-Giroux-Sttzle', 'Guentzel-Crosby-Rust', 'Reinhart-Barkov-Rodrigues',
             'Marchment-Seguin-Duchene', 'Joshua-Blueger-Garland', 'Zary-Kadri-Pospisil']


best = bestLines[bestLines['name'].isin(best)]
best[['lineId', 'name', 'team', 'season', 'line_score', 'rank']]
# Out:
#                       lineId                         name team  season  \
# 8661   847079484784498480027     Robertson-Pavelski-Hintz  DAL    2022
# 12292  847079484784498480027     Robertson-Pavelski-Hintz  DAL    2023
# 12929  847516884757948478975     Marchment-Seguin-Duchene  DAL    2023
# 3150   847167584758108477404         Guentzel-Crosby-Rust  PIT    2020
# 6717   847804784784838479318      Bunting-Matthews-Marner  TOR    2021
# 9311   847167584764838477404       Guentzel-Crosby-Rakell  PIT    2022
# 9051   847351284808018482116        Tkachuk-Giroux-Sttzle  OTT    2022
# 4996   847167584758108477404         Guentzel-Crosby-Rust  PIT    2021
# 12798  847415084763998478233  Mangiapane-Backlund-Coleman  CGY    2023
# 10109  847167584758108477404         Guentzel-Crosby-Rust  PIT    2022
# 9258   847168584779608482124        Byfield-Kopitar-Kempe  LAK    2022
# 8763   847063884734198478498    Debrusk-Bergeron-Marchand  BOS    2022
# 9041   847415084763998478233  Mangiapane-Backlund-Coleman  CGY    2022
# 13733  847749384779338478542    Reinhart-Barkov-Rodrigues  FLA    2023
# 9441   847793984780478479318    Bunting-Matthews-Nylander  TOR    2022
# 13301  847517284810288482074          Zary-Kadri-Pospisil  CGY    2023
# 11168  847692784780578478856       Joshua-Blueger-Garland  VAN    2023
# 12781  847167584758108477404         Guentzel-Crosby-Rust  PIT    2023
# 6977   847415084763998478233  Mangiapane-Backlund-Coleman  CGY    2021
# 5701   847063884734198478498    Debrusk-Bergeron-Marchand  BOS    2021
# 10866  847804784784838479318      Bunting-Matthews-Marner  TOR    2022
# 8875   848003984808298480830  Necas-Kotkaniemi-Svechnikov  CAR    2022
# 8931   847740984774938479314     Tkachuk-Barkov-Verhaeghe  FLA    2022
# 12299  847167584764838477404       Guentzel-Crosby-Rakell  PIT    2023
# 12808  847351284808018482116        Tkachuk-Giroux-Sttzle  OTT    2023
# 9038   847519384800028480188    Tatar-Hischier-Zetterlund  NJD    2022
# 10552  847127684757918477956         Hall-Krejci-Pastrnak  BOS    2022
# 5598   847793984780478479318    Bunting-Matthews-Nylander  TOR    2021
# 5927   847167584764838477404       Guentzel-Crosby-Rakell  PIT    2021
# 11782  848003984808298480830  Necas-Kotkaniemi-Svechnikov  CAR    2023
# 4165   847063884734198478498    Debrusk-Bergeron-Marchand  BOS    2020
# 11739  847740984774938479314     Tkachuk-Barkov-Verhaeghe  FLA    2023
#
#        line_score  rank
# 8661   173.036952     5
# 12292  163.730584     8
# 12929  149.331776    11
# 3150   148.500907    12
# 6717   130.213327    25
# 9311   127.896450    26
# 9051   122.193892    33
# 4996   120.400968    37
# 12798  112.431245    46
# 10109  110.195786    50
# 9258   109.862707    53
# 8763   103.190209    63
# 9041    99.143865    75
# 13733   94.763279    86
# 9441    93.952133    90
# 13301   89.772238   105
# 11168   87.971318   108
# 12781   87.928250   109
# 6977    85.414999   115
# 5701    76.016118   150
# 10866   71.325028   173
# 8875    61.372010   245
# 8931    58.100670   276
# 12299   53.236605   319
# 12808   50.564765   344
# 9038    48.223081   379
# 10552   43.189973   476
# 5598    37.125767   630
# 5927    29.259398   987
# 11782   24.023899  1487
# 4165    21.119403  1972
# 11739   17.910995  2833

# %%
bestLines[['lineId', 'name', 'team', 'season', 'line_score', 'rank']].sort_values(by='line_score', ascending=False).head(30)
# Out:
#                       lineId                         name team  season  \
# 7282   847634684774968479314    Gaudreau-Lindholm-Tkachuk  CGY    2021
# 12284  847638984785508482109   Lafrenire-Trocheck-Panarin  NYR    2023
# 6778   847079484784498480027     Robertson-Hintz-Pavelski  DAL    2021
# 12014  847467984751588476887    Forsberg-O'Reilly-Nyquist  NSH    2023
# 8661   847079484784498480027     Robertson-Pavelski-Hintz  DAL    2022
# 10858  847353384758558476921         Martinook-Staal-Fast  CAR    2022
# 12968  848001884815408483515   Slafkovsky-Suzuki-Caufield  MTL    2023
# 12292  847079484784498480027     Robertson-Pavelski-Hintz  DAL    2023
# 11893  847579984763928478891  Appleton-Lowry-Niederreiter  WPG    2023
# 310    847063884734198477956   Marchand-Bergeron-Pastrnak  BOS    2019
# 12929  847516884757948478975     Marchment-Seguin-Duchene  DAL    2023
# 3150   847167584758108477404         Guentzel-Crosby-Rust  PIT    2020
# 780    847060684716858480113        Iafallo-Kopitar-Brown  LAK    2019
# 12177  847168584779608482124        Kempe-Kopitar-Byfield  LAK    2023
# 7498   847692584785088479661       Jeannot-Sissons-Trenin  NSH    2021
# 6900   847569284774518478864  Kaprizov-Hartman-Zuccarello  MIN    2021
# 9193   847645384780108479542         Hagel-Point-Kucherov  TBL    2022
# 190    847519384758488476479      Tatar-Danault-Gallagher  MTL    2019
# 2197   847793384781098478403     Olofsson-Eichel-Reinhart  BUF    2019
# 5611   847062184740348477930       Maroon-Bellemare-Perry  TBL    2021
# 11663  847647984779428479675          Moore-Danault-Fiala  LAK    2023
# 2091   847414984764568477493     Huberdeau-Barkov-Dadonov  FLA    2019
# 9396   847578484779498479420        Skinner-Thompson-Tuch  BUF    2022
# 1840   847646084783988479339       Connor-Scheifele-Laine  WPG    2019
# 6717   847804784784838479318      Bunting-Matthews-Marner  TOR    2021
# 9311   847167584764838477404       Guentzel-Crosby-Rakell  PIT    2022
# 11099  847515184757548478115      Engvall-Nelson-Palmieri  NYI    2023
# 2894   847519184764488476539  Marchessault-Karlsson-Smith  VGK    2020
# 6501   847353384757998475855      Fast-Staal-Niederreiter  CAR    2021
# 9135   847647984780428479675      Moore-Danault-Arvidsson  LAK    2022
#
#        line_score  rank
# 7282   214.478488     1
# 12284  190.956693     2
# 6778   177.738458     3
# 12014  173.744052     4
# 8661   173.036952     5
# 10858  169.706207     6
# 12968  166.632719     7
# 12292  163.730584     8
# 11893  155.281594     9
# 310    150.454827    10
# 12929  149.331776    11
# 3150   148.500907    12
# 780    147.319939    13
# 12177  146.772161    14
# 7498   145.890570    15
# 6900   143.809914    16
# 9193   141.954891    17
# 190    135.898945    18
# 2197   135.791572    19
# 5611   135.031934    20
# 11663  134.903683    21
# 2091   134.890809    22
# 9396   131.787299    23
# 1840   130.431628    24
# 6717   130.213327    25
# 9311   127.896450    26
# 11099  127.473701    27
# 2894   127.063126    28
# 6501   126.419631    29
# 9135   125.341240    30

# %%
forwardsCols = pd.Series(forwards55.columns)
forwards55.head()
# Out:
#    playerId  season           name team position situation  games_played  \
# 0   8474641    2019  Adam Henrique  ANA        C      5on5            71
# 1   8474641    2020  Adam Henrique  ANA        C      5on5            45
# 2   8474641    2021  Adam Henrique  ANA        C      5on5            58
# 3   8474641    2022  Adam Henrique  ANA        C      5on5            62
# 4   8473986    2023   Alex Killorn  ANA        L      5on5            63
#
#    icetime  shifts  gameScore  ...  corsiForAfterShifts  \
# 0  55793.0  1275.0      48.82  ...                 47.0
# 1  34324.0   777.0      22.62  ...                 30.0
# 2  50470.0  1101.0      43.53  ...                 36.0
# 3  47265.0  1069.0      32.10  ...                 38.0
# 4  54790.0  1071.0      35.97  ...                 18.0
#
#    corsiAgainstAfterShifts  fenwickForAfterShifts  fenwickAgainstAfterShifts  \
# 0                     34.0                   34.0                       25.0
# 1                     18.0                   24.0                       11.0
# 2                     31.0                   28.0                       26.0
# 3                     18.0                   31.0                       14.0
# 4                     37.0                   16.0                       30.0
#
#     birthDate  weight  height  nationality  shootsCatches  primaryNumber
# 0  1990-02-06   197.0   6' 0"          CAN              L           14.0
# 1  1990-02-06   197.0   6' 0"          CAN              L           14.0
# 2  1990-02-06   197.0   6' 0"          CAN              L           14.0
# 3  1990-02-06   197.0   6' 0"          CAN              L           14.0
# 4  1989-09-14   196.0   6' 1"          CAN              L           17.0
#
# [5 rows x 160 columns]

# %% [markdown]
# In our lines data set we created our line score using the following data points with weights:
#
# - 'icetime': 0.15,
# - 'xGoalsPercentage': 0.3,
# - 'xGoalsFor': 0.25,
# - 'xGoalsAgainst': -0.25,
# - 'shotsOnGoalFor': 0.2,
# - 'shotsOnGoalAgainst': -0.25,  # Negative weight for shots against
# - 'goalsFor': 0.2,
# - 'goalsAgainst': -0.2,  # Negative weight for goals against
# - 'penaltiesFor': -0.05,  # Negative weight for penalties (you might want to penalize these) # Negative weight for penalty minutes
# - 'penaltiesAgainst': 0.1,
# - 'faceOffsWonFor': 0.1,
# - 'hitsFor': 0.1
#
# in our forwards data we will want to consider similar statistics and more:
#
# ** Need to keep in mind that these stats are for 5on5 only!
#
# - position (we need a C and 2 wings (L or R) on each line, with ideally a L and R winger)
# - games__played (if a player hasn't played many games, this indicates that they most likely no good)
# - onIce_xGoalsPercentage
# - I_F_xGoals
# - I_F_primaryAssists
# - I_F_secondaryAssists
# - I_F_shotsOnGoal
# - I_F_goals
# - I_F_points
# - I_F_hits
# - I_F_shifts
# - I_F_giveaways
# - I_F_takeaways
# - penalties
# - penalitiesDrawn
# - faceOffsWon
# - faceOffsLost
# - birthdate
# - height
# - weight
# - shootsCatches
# - OnIce_F_xGoals
# - OnIce_A_xGoals
# - OnIce_F_goals
# - OnIce_A_goals

# %%
features = [
    'playerId',
    'season',
    'name',
    'team',
    'birthDate',
    'height',
    'weight',
    'position',
    'shootsCatches',
    'games_played',
    'onIce_xGoalsPercentage',
    'OnIce_F_xGoals',
    'OnIce_A_xGoals',
    'OnIce_F_goals',
    'OnIce_A_goals',
    'I_F_xGoals',
    'I_F_primaryAssists',
    'I_F_secondaryAssists',
    'I_F_shotsOnGoal',
    'I_F_goals',
    'I_F_points',
    'I_F_hits',
    'I_F_shifts',
    'I_F_giveaways',
    'I_F_takeaways',
    'penalties',
    'penaltiesDrawn',
    'faceoffsWon',
    'faceoffsLost',
]

forwards55 = forwards55[features]
forwards55.columns = forwards55.columns = forwards55.columns.str.replace('I_F_', '')

forwards55[['firstName', 'lastName']] = forwards55['name'].str.split(' ', n=1, expand=True)

# Remove (pop) the columns you want to move
firstName = forwards55.pop('firstName')
lastName = forwards55.pop('lastName')

# Insert 
forwards55.insert(3, 'firstName', firstName)
forwards55.insert(4, 'lastName', lastName)
forwards55 = forwards55.drop(columns={'name'})


forwards55
# Out:
#       playerId  season firstName  lastName team   birthDate  height  weight  \
# 0      8474641    2019      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 1      8474641    2020      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 2      8474641    2021      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 3      8474641    2022      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 4      8473986    2023      Alex   Killorn  ANA  1989-09-14   6' 1"   196.0
# ...        ...     ...       ...       ...  ...         ...     ...     ...
# 4544   8476880    2020       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4545   8476880    2021       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4546   8476880    2022       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4547   8476880    2023       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4548   8476329    2019    Travis      Boyd  WSH  1993-09-14  5' 11"   185.0
#
#      position shootsCatches  ...  goals  points   hits  shifts  giveaways  \
# 0           C             L  ...   19.0    31.0   65.0  1275.0       25.0
# 1           C             L  ...   10.0    17.0   37.0   777.0       16.0
# 2           C             L  ...   11.0    28.0   18.0  1101.0       17.0
# 3           C             L  ...   15.0    25.0   26.0  1069.0       27.0
# 4           L             L  ...   11.0    24.0   64.0  1071.0       28.0
# ...       ...           ...  ...    ...     ...    ...     ...        ...
# 4544        R             R  ...    6.0    21.0   95.0   795.0       14.0
# 4545        R             R  ...   14.0    30.0  208.0  1340.0       38.0
# 4546        R             R  ...    5.0    11.0   90.0   556.0        7.0
# 4547        R             R  ...    6.0    15.0  200.0  1280.0       39.0
# 4548        C             R  ...    3.0     9.0   14.0   301.0        6.0
#
#       takeaways  penalties  penaltiesDrawn  faceoffsWon  faceoffsLost
# 0          21.0        9.0             9.0        379.0         326.0
# 1           9.0        4.0             4.0        232.0         196.0
# 2          17.0        6.0             6.0        176.0         151.0
# 3          14.0        8.0             7.0        131.0         120.0
# 4          23.0       18.0             8.0          8.0          18.0
# ...         ...        ...             ...          ...           ...
# 4544       13.0       18.0            17.0          8.0           5.0
# 4545       25.0       25.0            25.0         10.0          10.0
# 4546       10.0       21.0            15.0          3.0           5.0
# 4547       36.0       38.0            32.0          7.0          17.0
# 4548        7.0        1.0             2.0         48.0          59.0
#
# [2949 rows x 30 columns]

# %%
forwards55[['totalGoals', 'totalPrimaryAssists', 'totalShotsOnGoal', 'total_xGoals', 'totalPoints', 'totalPenaltiesDrawn', 'totalPenalties']] = forwards55[['goals', 'primaryAssists', 'shotsOnGoal', 'xGoals', 'points', 'penaltiesDrawn', 'penalties']]
forwards55['totalAssists'] = forwards55['primaryAssists'] + forwards55['secondaryAssists']
forwards55
# Out:
#       playerId  season firstName  lastName team   birthDate  height  weight  \
# 0      8474641    2019      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 1      8474641    2020      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 2      8474641    2021      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 3      8474641    2022      Adam  Henrique  ANA  1990-02-06   6' 0"   197.0
# 4      8473986    2023      Alex   Killorn  ANA  1989-09-14   6' 1"   196.0
# ...        ...     ...       ...       ...  ...         ...     ...     ...
# 4544   8476880    2020       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4545   8476880    2021       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4546   8476880    2022       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4547   8476880    2023       Tom    Wilson  WSH  1994-03-29   6' 4"   218.0
# 4548   8476329    2019    Travis      Boyd  WSH  1993-09-14  5' 11"   185.0
#
#      position shootsCatches  ...  faceoffsWon  faceoffsLost  totalGoals  \
# 0           C             L  ...        379.0         326.0        19.0
# 1           C             L  ...        232.0         196.0        10.0
# 2           C             L  ...        176.0         151.0        11.0
# 3           C             L  ...        131.0         120.0        15.0
# 4           L             L  ...          8.0          18.0        11.0
# ...       ...           ...  ...          ...           ...         ...
# 4544        R             R  ...          8.0           5.0         6.0
# 4545        R             R  ...         10.0          10.0        14.0
# 4546        R             R  ...          3.0           5.0         5.0
# 4547        R             R  ...          7.0          17.0         6.0
# 4548        C             R  ...         48.0          59.0         3.0
#
#       totalPrimaryAssists  totalShotsOnGoal  total_xGoals  totalPoints  \
# 0                     8.0             121.0         11.63         31.0
# 1                     5.0              58.0          5.03         17.0
# 2                    10.0             109.0         12.29         28.0
# 3                     4.0              94.0         10.51         25.0
# 4                    10.0             104.0         11.74         24.0
# ...                   ...               ...           ...          ...
# 4544                 10.0              57.0          5.16         21.0
# 4545                  7.0             102.0         10.21         30.0
# 4546                  4.0              52.0          4.97         11.0
# 4547                  4.0             116.0         11.58         15.0
# 4548                  5.0              21.0          2.18          9.0
#
#       totalPenaltiesDrawn  totalPenalties  totalAssists
# 0                     9.0             9.0          12.0
# 1                     4.0             4.0           7.0
# 2                     6.0             6.0          17.0
# 3                     7.0             8.0          10.0
# 4                     8.0            18.0          13.0
# ...                   ...             ...           ...
# 4544                 17.0            18.0          15.0
# 4545                 25.0            25.0          16.0
# 4546                 15.0            21.0           6.0
# 4547                 32.0            38.0           9.0
# 4548                  2.0             1.0           6.0
#
# [2949 rows x 38 columns]

# %%
agg_features = {
    # 'playerId': 'first',
    'season' : 'count',
    'firstName': 'first',
    'lastName': 'first',
    'team' : 'nunique',
    'birthDate' : 'first',
    'height' : 'first',
    'weight' : 'first',
    'position' : 'first',
    'shootsCatches' :'first',
    'games_played' : 'sum',
    'onIce_xGoalsPercentage' : 'mean',
    'OnIce_F_xGoals' : 'mean',
    'OnIce_A_xGoals' : 'mean',
    'OnIce_F_goals' : 'mean',
    'OnIce_A_goals' : 'mean',
    'xGoals' : 'mean',
    'primaryAssists' : 'mean',
    'secondaryAssists' : 'mean',
    'shotsOnGoal' : 'mean',
    'goals' : 'mean',
    'points' : 'mean',
    'hits' : 'mean',
    'shifts' : 'mean',
    'giveaways' : 'mean',
    'takeaways' : 'mean',
    'penalties' : 'mean',
    'penaltiesDrawn' : 'mean',
    'faceoffsWon' : 'mean',
    'faceoffsLost' : 'mean',
    'totalGoals':'sum',
    'totalPrimaryAssists': 'sum',
    'total_xGoals':'sum',
    'totalAssists':'sum',
    'totalPoints':'sum',
    'totalPenaltiesDrawn':'sum',
    'totalPenalties':'sum',
    'totalShotsOnGoal':'sum'
}

forwards = forwards55.groupby(['playerId']).agg(agg_features).reset_index()
forwards = forwards.rename(columns={'season' : 'seasons_played', 'team': 'teams_played_for',
                                    'goals':'avgGoals', 'points':'avgPoints'})

# %%
forwards['goalsPerGame'] = forwards['totalGoals']/forwards['games_played']
forwards['pointsPerGame'] = forwards['totalPoints']/forwards['games_played']

# %%
weights = {
    'games_played': 0.1,
    'onIce_xGoalsPercentage': 0.55,
    'OnIce_F_xGoals': 0.4,
    'OnIce_A_xGoals': -0.4,
    'OnIce_F_goals': 0.5,
    'OnIce_A_goals': -0.5,
    'xGoals': 0.55,
    'primaryAssists': 0.3,
    'secondaryAssists': 0.25,
    'shotsOnGoal': 0.1,
    'avgGoals': 0.5,
    'avgPoints': 0.4,
    'hits': 0.2,
    'shifts': 0.1,
    'giveaways': -0.2,
    'takeaways': 0.3,
    'penalties': -0.5,
    'penaltiesDrawn': 0.5,
    'faceoffsWon': 0.05,# this one is only really important for centres?
    'faceoffsLost': -0.05,
    'totalGoals': 0.2,
    'totalPrimaryAssists': 0.1,
    'total_xGoals': 0.2,
    'totalAssists': 0.15,
    'totalPoints': 0.2,
    'totalPenaltiesDrawn': 0.2,
    'totalPenalties': -0.35,
    'totalShotsOnGoal': 0.1
}

forwards55 = forwards.copy()

forwards55['score'] = forwards55[weights.keys()].dot(pd.Series(weights))
forwards55.sort_values(by='score', ascending=False).head(50)
# Out:
#      playerId  seasons_played   firstName     lastName  teams_played_for  \
# 518   8479318               5      Auston     Matthews                 1
# 442   8478402               5      Connor      McDavid                 1
# 339   8477492               5      Nathan    MacKinnon                 1
# 687   8480801               5       Brady      Tkachuk                 1
# 386   8477956               5       David     Pastrnak                 1
# 515   8479314               5     Matthew      Tkachuk                 2
# 369   8477934               5        Leon    Draisaitl                 1
# 373   8477939               5     William     Nylander                 1
# 446   8478414               5        Timo        Meier                 2
# 33    8471675               5      Sidney       Crosby                 1
# 198   8476346               5      Johnny     Gaudreau                 2
# 447   8478420               5       Mikko     Rantanen                 1
# 22    8471214               5        Alex     Ovechkin                 1
# 485   8478550               5      Artemi      Panarin                 1
# 402   8478010               5     Brayden        Point                 1
# 494   8478856               5       Conor      Garland                 2
# 473   8478483               5       Mitch       Marner                 1
# 117   8475166               5        John      Tavares                 1
# 163   8475786               5        Zach        Hyman                 2
# 439   8478398               5        Kyle       Connor                 1
# 553   8479407               5      Jesper        Bratt                 1
# 21    8470794               5         Joe     Pavelski                 1
# 236   8476468               5        J.T.       Miller                 1
# 227   8476453               4      Nikita     Kucherov                 1
# 619   8480012               5       Elias   Pettersson                 1
# 374   8477940               5     Nikolaj       Ehlers                 1
# 154   8475754               5       Brock       Nelson                 1
# 162   8475784               5        Jeff      Skinner                 1
# 121   8475172               5       Nazem        Kadri                 2
# 496   8478864               4      Kirill     Kaprizov                 1
# 526   8479343               5     Clayton       Keller                 1
# 208   8476399               5       Blake      Coleman                 2
# 233   8476460               5        Mark    Scheifele                 1
# 46    8473419               5        Brad     Marchand                 1
# 340   8477493               5  Aleksander       Barkov                 1
# 35    8471685               5        Anze      Kopitar                 1
# 344   8477500               5          Bo       Horvat                 2
# 342   8477496               5       Elias     Lindholm                 2
# 450   8478427               5   Sebastian          Aho                 1
# 261   8476887               5       Filip     Forsberg                 1
# 80    8474141               5     Patrick         Kane                 3
# 460   8478445               5      Mathew       Barzal                 1
# 239   8476479               5     Phillip      Danault                 2
# 317   8477416               5      Oliver  Bjorkstrand                 2
# 82    8474150               5      Mikael     Backlund                 1
# 456   8478439               5      Travis      Konecny                 1
# 232   8476459               5        Mika    Zibanejad                 1
# 368   8477933               4         Sam     Reinhart                 2
# 434   8478233               5      Andrew   Mangiapane                 1
# 95    8474586               5      Jordan       Eberle                 2
#
#       birthDate  height  weight position shootsCatches  ...  faceoffsLost  \
# 518  1997-09-17   6' 3"   223.0        C             L  ...         439.6
# 442  1997-01-13   6' 1"   193.0        C             L  ...         378.4
# 339  1995-09-01   6' 0"   205.0        C             R  ...         442.4
# 687  1999-09-16   6' 3"   196.0        L             L  ...         110.2
# 386  1996-05-25   6' 0"   194.0        R             R  ...           8.6
# 515  1997-12-11   6' 2"   202.0        L             L  ...           7.0
# 369  1995-10-27   6' 2"   208.0        C             L  ...         411.4
# 373  1996-05-01   6' 0"   191.0        R             R  ...          41.2
# 446  1996-10-08   6' 0"   210.0        R             L  ...          22.8
# 33   1987-08-07  5' 11"   200.0        C             L  ...         502.6
# 198  1993-08-13   5' 9"   165.0        L             L  ...           0.0
# 447  1996-10-29   6' 4"   215.0        R             L  ...         102.4
# 22   1985-09-17   6' 3"   235.0        L             R  ...           3.2
# 485  1991-10-30  5' 11"   168.0        L             R  ...           3.4
# 402  1996-03-13  5' 10"   166.0        C             R  ...         287.4
# 494  1996-03-11  5' 10"   165.0        R             R  ...           6.8
# 473  1997-05-05   6' 0"   175.0        R             R  ...           3.6
# 117  1990-09-20   6' 1"   209.0        C             L  ...         370.0
# 163  1992-06-09   6' 1"   209.0        L             R  ...          14.6
# 439  1996-12-09   6' 1"   182.0        L             L  ...           4.6
# 553  1998-07-30  5' 10"   175.0        L             L  ...           4.8
# 21   1984-07-11  5' 11"   190.0        C             R  ...         248.8
# 236  1993-03-14   6' 1"   218.0        C             L  ...         305.8
# 227  1993-06-17  5' 11"   178.0        R             L  ...           0.0
# 619  1998-11-12   6' 2"   176.0        C             L  ...         250.2
# 374  1996-02-14   6' 0"   172.0        L             L  ...           2.2
# 154  1991-10-15   6' 3"   212.0        C             L  ...         392.2
# 162  1992-05-16  5' 11"   187.0        L             L  ...          66.2
# 121  1990-10-06   6' 0"   192.0        C             L  ...         381.4
# 496  1997-04-26   5' 9"   201.0        L             L  ...           4.0
# 526  1998-07-29  5' 10"   170.0        R             L  ...          19.8
# 208  1991-11-28  5' 11"   200.0        C             L  ...          22.4
# 233  1993-03-15   6' 3"   207.0        C             R  ...         431.8
# 46   1988-05-11   5' 9"   181.0        L             L  ...          20.6
# 340  1995-09-02   6' 3"   213.0        C             L  ...         347.8
# 35   1987-08-24   6' 3"   225.0        C             L  ...         418.6
# 344  1995-04-05   6' 0"   215.0        C             L  ...         467.6
# 342  1994-12-02   6' 1"   195.0        C             R  ...         389.8
# 450  1997-07-26   6' 0"   176.0        C             L  ...         358.2
# 261  1994-08-13   6' 1"   205.0        L             R  ...           3.0
# 80   1988-11-19  5' 10"   177.0        R             L  ...           1.4
# 460  1997-05-26   6' 0"   187.0        C             R  ...         194.0
# 239  1993-02-24   6' 1"   198.0        C             L  ...         395.8
# 317  1995-04-10   6' 0"   177.0        R             R  ...          16.0
# 82   1989-03-17   6' 0"   200.0        C             L  ...         422.4
# 456  1997-03-11  5' 10"   175.0        R             R  ...          22.4
# 232  1993-04-18   6' 2"   213.0        C             R  ...         411.8
# 368  1995-11-06   6' 1"   192.0        C             R  ...         123.0
# 434  1996-04-04  5' 10"   184.0        L             L  ...          17.2
# 95   1990-05-15  5' 11"   187.0        R             R  ...          18.4
#
#      totalGoals  totalPrimaryAssists  total_xGoals  totalAssists  totalPoints  \
# 518       161.0                 76.0        115.63         109.0        270.0
# 442       115.0                122.0         96.13         183.0        298.0
# 339       110.0                119.0         78.11         170.0        280.0
# 687        85.0                 74.0        100.83         100.0        185.0
# 386       124.0                 79.0         82.31         117.0        241.0
# 515        84.0                 85.0         81.42         136.0        220.0
# 369        94.0                105.0         61.33         163.0        257.0
# 373        91.0                 70.0         79.83         107.0        198.0
# 446        84.0                 55.0         87.65          91.0        175.0
# 33         80.0                 83.0         71.32         125.0        205.0
# 198        68.0                101.0         63.74         136.0        204.0
# 447       100.0                 64.0         70.33         110.0        210.0
# 22        100.0                 50.0         77.30          79.0        179.0
# 485        94.0                 91.0         48.55         153.0        247.0
# 402       101.0                 62.0         78.89         108.0        209.0
# 494        74.0                 63.0         58.85         100.0        174.0
# 473        77.0                108.0         56.52         161.0        238.0
# 117        70.0                 56.0         91.89         100.0        170.0
# 163        93.0                 50.0        104.95          92.0        185.0
# 439       107.0                 49.0         76.34          82.0        189.0
# 553        75.0                 71.0         68.27         113.0        188.0
# 21         55.0                 60.0         63.66         108.0        163.0
# 236        77.0                 68.0         59.41         116.0        193.0
# 227        70.0                 77.0         54.91         130.0        200.0
# 619        75.0                 68.0         55.11         110.0        185.0
# 374        80.0                 69.0         56.55         105.0        185.0
# 154        93.0                 56.0         70.83          91.0        184.0
# 162        85.0                 56.0         75.61          82.0        167.0
# 121        64.0                 72.0         60.92         110.0        174.0
# 496        80.0                 66.0         59.51          96.0        176.0
# 526        85.0                 67.0         60.11          95.0        180.0
# 208        71.0                 36.0         79.62          79.0        150.0
# 233        80.0                 68.0         64.78         117.0        197.0
# 46         82.0                 70.0         64.91         106.0        188.0
# 340        68.0                 70.0         64.22         112.0        180.0
# 35         63.0                 63.0         56.24         103.0        166.0
# 344        64.0                 56.0         61.14          90.0        154.0
# 342        69.0                 45.0         56.01          90.0        159.0
# 450        84.0                 67.0         73.85          94.0        178.0
# 261        89.0                 46.0         71.23          75.0        164.0
# 80         75.0                 78.0         51.17         121.0        196.0
# 460        63.0                 84.0         57.23         120.0        183.0
# 239        65.0                 57.0         65.85          98.0        163.0
# 317        74.0                 54.0         61.06          83.0        157.0
# 82         49.0                 59.0         65.60          94.0        143.0
# 456        75.0                 63.0         62.43          94.0        169.0
# 232        65.0                 71.0         50.68         102.0        167.0
# 368        59.0                 59.0         55.78          90.0        149.0
# 434        75.0                 58.0         72.72          80.0        155.0
# 95         67.0                 58.0         62.82          90.0        157.0
#
#      totalPenaltiesDrawn  totalPenalties  totalShotsOnGoal      score
# 518                 78.0            26.0            1082.0  551.94440
# 442                155.0            61.0             867.0  524.44170
# 339                131.0            56.0            1030.0  515.10030
# 687                169.0           145.0            1011.0  487.67980
# 386                109.0            63.0            1006.0  476.98550
# 515                154.0           129.0             732.0  434.27270
# 369                 89.0            65.0             595.0  425.78500
# 373                 66.0            37.0             824.0  424.39080
# 446                 96.0            84.0             922.0  421.99780
# 33                  80.0            59.0             693.0  416.26000
# 198                 89.0            27.0             652.0  407.95350
# 447                 98.0            95.0             703.0  407.69290
# 22                  54.0            46.0             806.0  404.94440
# 485                 67.0            38.0             635.0  403.91450
# 402                 75.0            23.0             582.0  403.48210
# 494                116.0            51.0             721.0  402.53940
# 473                 59.0            40.0             546.0  402.10800
# 117                 72.0            56.0             738.0  401.49630
# 163                 75.0            62.0             743.0  400.70010
# 439                 40.0            26.0             791.0  397.90320
# 553                 57.0            17.0             665.0  396.92420
# 21                  87.0            30.0             562.0  394.04790
# 236                 69.0            87.0             530.0  390.58380
# 227                 77.0            45.0             607.0  390.49925
# 619                122.0            25.0             492.0  385.92190
# 374                105.0            36.0             738.0  382.84940
# 154                 67.0            46.0             631.0  382.70460
# 162                106.0            49.0             773.0  382.69720
# 121                142.0            91.0             737.0  382.30660
# 496                103.0            44.0             587.0  380.91575
# 526                107.0            61.0             646.0  380.90340
# 208                 82.0           103.0             786.0  377.42440
# 233                100.0            53.0             509.0  375.20320
# 46                 156.0           128.0             611.0  374.54800
# 340                 65.0            36.0             601.0  373.77340
# 35                  61.0            28.0             521.0  373.61380
# 344                 61.0            53.0             635.0  372.98540
# 342                 55.0            36.0             571.0  372.49990
# 450                 77.0            70.0             620.0  372.14780
# 261                 83.0            48.0             703.0  371.47820
# 80                  54.0            33.0             715.0  370.56040
# 460                 94.0            56.0             606.0  368.60510
# 239                 67.0            63.0             564.0  368.25950
# 317                 59.0            27.0             667.0  367.24470
# 82                  36.0            55.0             728.0  367.22780
# 456                111.0            77.0             654.0  366.36800
# 232                 76.0            37.0             571.0  366.03090
# 368                 43.0            19.0             489.0  363.07075
# 434                 75.0            58.0             544.0  361.41900
# 95                  50.0            41.0             621.0  360.58810
#
# [50 rows x 39 columns]
